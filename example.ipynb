# %%
import bittensor.core.subtensor as btcs
import heapq
import requests
from datetime import datetime
import time
import json
from pprint import pprint
import os
import json
from pathlib import Path
import psutil
import os
# Out:
# current block:
# 6712837
# current_register_fee:
# τ0.002831807
